# %% [markdown]
# ### Perform analysis on the sentences itself (those for which we have labels)

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
from collections import Counter
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\basti\\PycharmProjects\\ai_thesis\\data_analysis'

# %%
sample_200 = pd.read_csv('../files/datasets/labeled/l01_reuters_sample200.csv')
sample_800 = pd.read_csv('../files/datasets/labeled/l02_reuters_sample800.csv')

# %%
labeled_sentences = pd.concat([sample_200, sample_800])
labeled_sentences.drop('Unnamed: 0', axis=1)
# Out:
#                                               sentence      id  article_id  \
# 0    The automaker also said it is considering intr...     186          43
# 1                        It fell 12 percent last year.     274          63
# 2    Dozens of companies in the sector merged in th...    2540         615
# 3    Annual revenues for the government IT business...    3313         782
# 4    The Swedish crown rose versus the dollar and e...    4024         936
# ..                                                 ...     ...         ...
# 795  OTHER BIDDERS              A Pfizer move on As...  109689       16753
# 796               The driver of a 2003 CTS, in a co...  109823       16770
# 797   Barra also met with accident victims' familie...  110083       16907
# 798  The additional 14 deaths occurred after the 13...  110089       16907
# 799               A February 2005 entry in the cong...  110111       16915
#
#      valence  arousal  is_annotated  is_miscellaneous  rank_value is_drafted  \
# 0       0.64     0.51          True             False        0.01        NaN
# 1       0.39     0.49          True             False        0.66        NaN
# 2       0.50     0.70          True             False        0.87        NaN
# 3       0.36     0.54          True             False        0.67        NaN
# 4       0.55     0.39          True             False        0.34        NaN
# ..       ...      ...           ...               ...         ...        ...
# 795     0.58     0.64          True             False         NaN       True
# 796     0.32     0.55          True             False         NaN       True
# 797     0.39     0.58          True             False         NaN       True
# 798     0.23     0.69          True             False         NaN       True
# 799     0.63     0.60          True             False         NaN       True
#
#      rank_idx                   draft_time
# 0         NaN                          NaN
# 1         NaN                          NaN
# 2         NaN                          NaN
# 3         NaN                          NaN
# 4         NaN                          NaN
# ..        ...                          ...
# 795     504.0  2022-08-25T09:40:51.0593080
# 796     263.0  2022-06-23T09:57:25.3611610
# 797     372.0  2022-08-25T09:26:12.3074480
# 798     416.0  2022-07-19T16:17:36.8375170
# 799     364.0  2022-07-01T13:52:20.6840740
#
# [1000 rows x 11 columns]

# %%
# load spacy model
nlp = spacy.load('en_core_web_sm')

# %%
labeled_sentences['sentence_nlp'] = labeled_sentences['sentence'].apply(nlp)

# %%
# add number of tokens
labeled_sentences['num_tokens'] = labeled_sentences['sentence_nlp'].apply(len)
labeled_sentences.head()
# Out:
#    Unnamed: 0                                           sentence    id  \
# 0         0.0  The automaker also said it is considering intr...   186
# 1         1.0                      It fell 12 percent last year.   274
# 2         2.0  Dozens of companies in the sector merged in th...  2540
# 3         3.0  Annual revenues for the government IT business...  3313
# 4         4.0  The Swedish crown rose versus the dollar and e...  4024
#
#    article_id  valence  arousal  is_annotated  is_miscellaneous  rank_value  \
# 0          43     0.64     0.51          True             False        0.01
# 1          63     0.39     0.49          True             False        0.66
# 2         615     0.50     0.70          True             False        0.87
# 3         782     0.36     0.54          True             False        0.67
# 4         936     0.55     0.39          True             False        0.34
#
#   is_drafted  rank_idx draft_time  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
#                                         sentence_nlp  num_tokens
# 0  (The, automaker, also, said, it, is, consideri...          21
# 1             (It, fell, 12, percent, last, year, .)           7
# 2  (Dozens, of, companies, in, the, sector, merge...          23
# 3  (Annual, revenues, for, the, government, IT, b...          31
# 4  (The, Swedish, crown, rose, versus, the, dolla...          39

# %%
def count_words(tweet):
  word_frequencies = Counter()
  words = []
  for token in tweet:
    if not token.is_punct:
      words.append(token.text)
  word_frequencies.update(words)
  return word_frequencies

# %%
labeled_sentences['word_dict'] = labeled_sentences['sentence_nlp'].apply(count_words)
labeled_sentences.head()
# Out:
#    Unnamed: 0                                           sentence    id  \
# 0         0.0  The automaker also said it is considering intr...   186
# 1         1.0                      It fell 12 percent last year.   274
# 2         2.0  Dozens of companies in the sector merged in th...  2540
# 3         3.0  Annual revenues for the government IT business...  3313
# 4         4.0  The Swedish crown rose versus the dollar and e...  4024
#
#    article_id  valence  arousal  is_annotated  is_miscellaneous  rank_value  \
# 0          43     0.64     0.51          True             False        0.01
# 1          63     0.39     0.49          True             False        0.66
# 2         615     0.50     0.70          True             False        0.87
# 3         782     0.36     0.54          True             False        0.67
# 4         936     0.55     0.39          True             False        0.34
#
#   is_drafted  rank_idx draft_time  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
#                                         sentence_nlp  num_tokens  \
# 0  (The, automaker, also, said, it, is, consideri...          21
# 1             (It, fell, 12, percent, last, year, .)           7
# 2  (Dozens, of, companies, in, the, sector, merge...          23
# 3  (Annual, revenues, for, the, government, IT, b...          31
# 4  (The, Swedish, crown, rose, versus, the, dolla...          39
#
#                                            word_dict
# 0  {'The': 1, 'automaker': 1, 'also': 1, 'said': ...
# 1  {'It': 1, 'fell': 1, '12': 1, 'percent': 1, 'l...
# 2  {'Dozens': 1, 'of': 2, 'companies': 1, 'in': 2...
# 3  {'Annual': 1, 'revenues': 1, 'for': 1, 'the': ...
# 4  {'The': 1, 'Swedish': 1, 'crown': 1, 'rose': 1...

# %%
def total_wc(word_dict):
  return sum(word_dict.values())

# %%
labeled_sentences['num_words'] = labeled_sentences['word_dict'].apply(total_wc)
labeled_sentences.head()
# Out:
#    Unnamed: 0                                           sentence    id  \
# 0         0.0  The automaker also said it is considering intr...   186
# 1         1.0                      It fell 12 percent last year.   274
# 2         2.0  Dozens of companies in the sector merged in th...  2540
# 3         3.0  Annual revenues for the government IT business...  3313
# 4         4.0  The Swedish crown rose versus the dollar and e...  4024
#
#    article_id  valence  arousal  is_annotated  is_miscellaneous  rank_value  \
# 0          43     0.64     0.51          True             False        0.01
# 1          63     0.39     0.49          True             False        0.66
# 2         615     0.50     0.70          True             False        0.87
# 3         782     0.36     0.54          True             False        0.67
# 4         936     0.55     0.39          True             False        0.34
#
#   is_drafted  rank_idx draft_time  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
#                                         sentence_nlp  num_tokens  \
# 0  (The, automaker, also, said, it, is, consideri...          21
# 1             (It, fell, 12, percent, last, year, .)           7
# 2  (Dozens, of, companies, in, the, sector, merge...          23
# 3  (Annual, revenues, for, the, government, IT, b...          31
# 4  (The, Swedish, crown, rose, versus, the, dolla...          39
#
#                                            word_dict  num_words
# 0  {'The': 1, 'automaker': 1, 'also': 1, 'said': ...         19
# 1  {'It': 1, 'fell': 1, '12': 1, 'percent': 1, 'l...          6
# 2  {'Dozens': 1, 'of': 2, 'companies': 1, 'in': 2...         22
# 3  {'Annual': 1, 'revenues': 1, 'for': 1, 'the': ...         28
# 4  {'The': 1, 'Swedish': 1, 'crown': 1, 'rose': 1...         36

# %%
def total_types(word_dict):
  return len(word_dict.keys())

# %%
labeled_sentences['num_types'] = labeled_sentences['word_dict'].apply(total_types)
labeled_sentences.head()
# Out:
#    Unnamed: 0                                           sentence    id  \
# 0         0.0  The automaker also said it is considering intr...   186
# 1         1.0                      It fell 12 percent last year.   274
# 2         2.0  Dozens of companies in the sector merged in th...  2540
# 3         3.0  Annual revenues for the government IT business...  3313
# 4         4.0  The Swedish crown rose versus the dollar and e...  4024
#
#    article_id  valence  arousal  is_annotated  is_miscellaneous  rank_value  \
# 0          43     0.64     0.51          True             False        0.01
# 1          63     0.39     0.49          True             False        0.66
# 2         615     0.50     0.70          True             False        0.87
# 3         782     0.36     0.54          True             False        0.67
# 4         936     0.55     0.39          True             False        0.34
#
#   is_drafted  rank_idx draft_time  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
#                                         sentence_nlp  num_tokens  \
# 0  (The, automaker, also, said, it, is, consideri...          21
# 1             (It, fell, 12, percent, last, year, .)           7
# 2  (Dozens, of, companies, in, the, sector, merge...          23
# 3  (Annual, revenues, for, the, government, IT, b...          31
# 4  (The, Swedish, crown, rose, versus, the, dolla...          39
#
#                                            word_dict  num_words  num_types
# 0  {'The': 1, 'automaker': 1, 'also': 1, 'said': ...         19         19
# 1  {'It': 1, 'fell': 1, '12': 1, 'percent': 1, 'l...          6          6
# 2  {'Dozens': 1, 'of': 2, 'companies': 1, 'in': 2...         22         17
# 3  {'Annual': 1, 'revenues': 1, 'for': 1, 'the': ...         28         22
# 4  {'The': 1, 'Swedish': 1, 'crown': 1, 'rose': 1...         36         35

# %%
# compute average word length
def avg_word_length(word_dict):
  total_word_length = sum([len(word) for word in word_dict.keys()])
  return total_word_length/sum(word_dict.values())

# %%
labeled_sentences['avg_word_length'] = labeled_sentences['word_dict'].apply(avg_word_length)
labeled_sentences.head()
# Out:
#    Unnamed: 0                                           sentence    id  \
# 0         0.0  The automaker also said it is considering intr...   186
# 1         1.0                      It fell 12 percent last year.   274
# 2         2.0  Dozens of companies in the sector merged in th...  2540
# 3         3.0  Annual revenues for the government IT business...  3313
# 4         4.0  The Swedish crown rose versus the dollar and e...  4024
#
#    article_id  valence  arousal  is_annotated  is_miscellaneous  rank_value  \
# 0          43     0.64     0.51          True             False        0.01
# 1          63     0.39     0.49          True             False        0.66
# 2         615     0.50     0.70          True             False        0.87
# 3         782     0.36     0.54          True             False        0.67
# 4         936     0.55     0.39          True             False        0.34
#
#   is_drafted  rank_idx draft_time  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
#                                         sentence_nlp  num_tokens  \
# 0  (The, automaker, also, said, it, is, consideri...          21
# 1             (It, fell, 12, percent, last, year, .)           7
# 2  (Dozens, of, companies, in, the, sector, merge...          23
# 3  (Annual, revenues, for, the, government, IT, b...          31
# 4  (The, Swedish, crown, rose, versus, the, dolla...          39
#
#                                            word_dict  num_words  num_types  \
# 0  {'The': 1, 'automaker': 1, 'also': 1, 'said': ...         19         19
# 1  {'It': 1, 'fell': 1, '12': 1, 'percent': 1, 'l...          6          6
# 2  {'Dozens': 1, 'of': 2, 'companies': 1, 'in': 2...         22         17
# 3  {'Annual': 1, 'revenues': 1, 'for': 1, 'the': ...         28         22
# 4  {'The': 1, 'Swedish': 1, 'crown': 1, 'rose': 1...         36         35
#
#    avg_word_length
# 0         5.315789
# 1         3.833333
# 2         3.772727
# 3         3.785714
# 4         4.500000

# %%
def extract_dict(df, dict_col):
  word_dict = {}
  for i, row in df.iterrows():
    word_dict.update(row[dict_col])
  return word_dict

# %%
word_dict = {}

for i, row in labeled_sentences.iterrows():
  word_dict.update(row['word_dict'])

# %%
num_tokens = np.sum(labeled_sentences['num_tokens'].values)
num_words = sum(labeled_sentences['num_words'].values)

res_dict = {
    'num_tokens': num_tokens ,
    'num_words': num_words,
    'num_types': len(word_dict.keys()),
    'avg_words_per_tweet': num_words/len(labeled_sentences),
    'avg_word_length': np.mean(labeled_sentences['avg_word_length'].values)
}

# %%
# convert to latex output

res_df = pd.DataFrame([res_dict])
print(res_df.T.to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &             0 \\
# \midrule
# num\_tokens          &  27772.000000 \\
# num\_words           &  24649.000000 \\
# num\_types           &   5944.000000 \\
# avg\_words\_per\_tweet &     24.649000 \\
# avg\_word\_length     &      4.719246 \\
# \bottomrule
# \end{tabular}
# C:\Users\basti\AppData\Local\Temp\ipykernel_9264\3581658971.py:4: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(res_df.T.to_latex())
